# %%
import pandas as pd

# %%
serie = pd.Series([11,15,12,13,14,12,11,11,10,14,16,16,14],index=["Fred","Jeanne","Julie","Julien",
"Chloé","Alex","Nicolas","Alice","Mathéo","Zoé","Maél","Catherine","Ines"])
print(serie)
# Out:
# Fred         11
# Jeanne       15
# Julie        12
# Julien       13
# Chloé        14
# Alex         12
# Nicolas      11
# Alice        11
# Mathéo       10
# Zoé          14
# Maél         16
# Catherine    16
# Ines         14
# dtype: int64

# %% [markdown]
# ## premiere idée sur la distribution de la série

# %%
#exemple
#75% 14.0 => 75% des eleves ont 14 ans ou moins
#25% 11.0 => 25% des eleves ont 14 ans ou moins

# %%
serie.describe()
# Out:
# count    13.0
# mean     13.0
# std       2.0
# min      10.0
# 25%      11.0
# 50%      13.0
# 75%      14.0
# max      16.0
# dtype: float64

# %%
serie["Julien"]
# Out:
# 13

# %%
serie[3]
# Out:
# 13

# %%
serie[["Julien","Julie", "Mathéo"]]
# Out:
# Julien    13
# Julie     12
# Mathéo    10
# dtype: int64

# %%
serie.min()
# Out:
# 10

# %%
serie.max()
# Out:
# 16

# %%
serie[serie>12]
# Out:
# Jeanne       15
# Julien       13
# Chloé        14
# Zoé          14
# Maél         16
# Catherine    16
# Ines         14
# dtype: int64

# %%
serie>12
# Out:
# Fred         False
# Jeanne        True
# Julie        False
# Julien        True
# Chloé         True
# Alex         False
# Nicolas      False
# Alice        False
# Mathéo       False
# Zoé           True
# Maél          True
# Catherine     True
# Ines          True
# dtype: bool

# %% [markdown]
# ### creation de dataframe apartir d'un array numpy

# %%
import numpy as np

# %%
houses = np.genfromtxt("Houses.csv",delimiter=",", dtype=int)

# %%
houses
# Out:
# array([[212000,   4148,  25264],
#        [230000,   2501,  11891],
#        [339000,   4374,  25351],
#        [289000,   2398,  22215],
#        [160000,   2536,   9234],
#        [ 85000,   2368,  13329],
#        [ 85000,   1264,   8407],
#        [145000,   1572,  12588],
#        [164000,   2375,  16204],
#        [123500,   1161,   9626],
#        [180000,   1542,   8755],
#        [159500,   1464,  14636],
#        [156000,   2240,  21780],
#        [146500,   1269,  11250],
#        [101500,    924,   7361],
#        [109800,    768,  10497],
#        [182000,   1320,  15768],
#        [110000,   1845,  12153],
#        [125000,   1274,  13634],
#        [ 80000,   1905,  10890]])

# %% [markdown]
# ## convertir un array numpy en dataframe

# %%
dataframe = pd.DataFrame(houses, columns=["prix","taille de la maison","surface du terrain"])

# %%
dataframe
# Out:
#       prix  taille de la maison  surface du terrain
# 0   212000                 4148               25264
# 1   230000                 2501               11891
# 2   339000                 4374               25351
# 3   289000                 2398               22215
# 4   160000                 2536                9234
# 5    85000                 2368               13329
# 6    85000                 1264                8407
# 7   145000                 1572               12588
# 8   164000                 2375               16204
# 9   123500                 1161                9626
# 10  180000                 1542                8755
# 11  159500                 1464               14636
# 12  156000                 2240               21780
# 13  146500                 1269               11250
# 14  101500                  924                7361
# 15  109800                  768               10497
# 16  182000                 1320               15768
# ...

# %% [markdown]
# ### Remaque UNE SERIE = UNE COLONNE

# %%
groupe1 = pd.Series([11,15,12,13,14,12,11,11,10,14,16,16,14],index=["Fred","Jeanne","Julie","Julien",
"Chloé","Alex","Nicolas","Alice","Mathéo","Zoé","Maél","Catherine","Ines"])
print(groupe1)
# Out:
# Fred         11
# Jeanne       15
# Julie        12
# Julien       13
# Chloé        14
# Alex         12
# Nicolas      11
# Alice        11
# Mathéo       10
# Zoé          14
# Maél         16
# Catherine    16
# Ines         14
# dtype: int64

# %%
groupe2 = pd.Series([11,15,15,11,14,12,11,13,10,14,16,16,9],index=["Fred",
"Jeanne","Damien","Grace","Chloé","Alex","Nicolas","Julien","Mathéo","Zoé","Maél","Catherine","Samuel"])

# %%
groupe2
# Out:
# Fred         11
# Jeanne       15
# Damien       15
# Grace        11
# Chloé        14
# Alex         12
# Nicolas      11
# Julien       13
# Mathéo       10
# Zoé          14
# Maél         16
# Catherine    16
# Samuel        9
# dtype: int64

# %%
dataframe = pd.DataFrame({"Groupe1":groupe1,"Groupe2":groupe2})

# %%
#NAN not available valeur manquante

# %%
dataframe
# Out:
#            Groupe1  Groupe2
# Alex          12.0     12.0
# Alice         11.0      NaN
# Catherine     16.0     16.0
# Chloé         14.0     14.0
# Damien         NaN     15.0
# Fred          11.0     11.0
# Grace          NaN     11.0
# Ines          14.0      NaN
# Jeanne        15.0     15.0
# Julie         12.0      NaN
# Julien        13.0     13.0
# Mathéo        10.0     10.0
# Maél          16.0     16.0
# Nicolas       11.0     11.0
# Samuel         NaN      9.0
# Zoé           14.0     14.0

# %%
google_app = pd.read_table('GooglePlayStore.csv',sep=',')

# %%
type(google_app)
# Out:
# pandas.core.frame.DataFrame

# %%
google_app = pd.read_csv("GooglePlayStore.csv")

# %%
google_app
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
google_app.shape
# Out:
# (10841, 13)

# %%
google_app.ndim
# Out:
# 2

# %%
google_app["Type"][10008]
# Out:
# 'Free'

# %% [markdown]
# ## ecrire le dataframe dans un fichier csv

# %%
google_app.to_csv("mon_dataframe.csv")

# %% [markdown]
# ## modification de l'index => la premire colonne ;)

# %%
google_app.set_index("App")
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
google_app_index = google_app.set_index("App")

# %%
google_app_index
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %%
#acceder au élements d'un dataframe
#Méthode iloc -> on utilise les indexs
#Méthode loc -> on utilise les noms

# %%
#google_app_index.iloc[0,1] 0-> ligne et 1->colonne

# %%
google_app_index.iloc[0,1]
# Out:
# 4.1

# %%
google_app_index.loc["Photo Editor & Candy Camera & Grid & ScrapBook","Category"]
# Out:
# 'ART_AND_DESIGN'

# %%
google_app_index.loc["Udemy - Online Courses",:]
# Out:
#                          Category  Rating Reviews Size    Installs  Type  \
# App
# Udemy - Online Courses  EDUCATION     4.5   99020  18M  1,000,000+  Free
# Udemy - Online Courses  EDUCATION     4.5   99020  18M  1,000,000+  Free
# Udemy - Online Courses  EDUCATION     4.5   99020  18M  1,000,000+  Free
#
#                        Price Content Rating     Genres    Last Updated  \
# App
# Udemy - Online Courses     0       Everyone  Education  August 2, 2018
# Udemy - Online Courses     0       Everyone  Education  August 2, 2018
# Udemy - Online Courses     0       Everyone  Education  August 2, 2018
#
#                        Current Ver Android Ver
# App
# Udemy - Online Courses       5.0.4  5.0 and up
# Udemy - Online Courses       5.0.4  5.0 and up
# Udemy - Online Courses       5.0.4  5.0 and up

# %%
google_app_index.iloc[:4,:]
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
#
#                                                    Reviews  Size     Installs  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159   19M      10,000+
# Coloring book moana                                    967   14M     500,000+
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510  8.7M   5,000,000+
# Sketch - Draw & Paint                               215644   25M  50,000,000+
#
#                                                     Type Price Content Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      Free     0       Everyone
# ...

# %%
#afficher toute les lignes des 4 premiere colonnes

# %%
google_app_index.iloc[:,:4].head()
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
#
#                                                    Reviews  Size
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159   19M
# Coloring book moana                                    967   14M
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510  8.7M
# Sketch - Draw & Paint                               215644   25M
# Pixel Draw - Number Art Coloring Book                  967  2.8M

# %%
google_app_index.loc[:,["Category","Rating","Reviews","Size"]].head()
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
#
#                                                    Reviews  Size
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159   19M
# Coloring book moana                                    967   14M
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510  8.7M
# Sketch - Draw & Paint                               215644   25M
# Pixel Draw - Number Art Coloring Book                  967  2.8M

# %%
google_app_index.iloc[2:5,3:8]
# Out:
#                                                     Size     Installs  Type  \
# App
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  8.7M   5,000,000+  Free
# Sketch - Draw & Paint                                25M  50,000,000+  Free
# Pixel Draw - Number Art Coloring Book               2.8M     100,000+  Free
#
#                                                    Price Content Rating
# App
# U Launcher Lite – FREE Live Cool Themes, Hide Apps     0       Everyone
# Sketch - Draw & Paint                                  0           Teen
# Pixel Draw - Number Art Coloring Book                  0       Everyone

# %%
category = google_app_index["Category"]

# %%
category
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook             ART_AND_DESIGN
# Coloring book moana                                        ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps         ART_AND_DESIGN
# Sketch - Draw & Paint                                      ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                      ART_AND_DESIGN
#                                                              ...
# Sya9a Maroc - FR                                                   FAMILY
# Fr. Mike Schmitz Audio Teachings                                   FAMILY
# Parkinson Exercices FR                                            MEDICAL
# The SCP Foundation DB fr nn5n                         BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                   LIFESTYLE
# Name: Category, Length: 10841, dtype: object

# %% [markdown]
# ## Ajouter une colonne a une dataframe

# %%
google_app_index["Category_bis"]=category

# %%
google_app_index.head()
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
#
#                                                    Reviews  Size     Installs  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159   19M      10,000+
# Coloring book moana                                    967   14M     500,000+
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510  8.7M   5,000,000+
# Sketch - Draw & Paint                               215644   25M  50,000,000+
# Pixel Draw - Number Art Coloring Book                  967  2.8M     100,000+
#
# ...

# %%
#axis = 1 toutes les colonnes
#axis = 0 toutes les lignes

# %%
google_app_index.drop(["Category_bis","Android Ver"], axis=1).head()
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
#
#                                                    Reviews  Size     Installs  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook         159   19M      10,000+
# Coloring book moana                                    967   14M     500,000+
# U Launcher Lite – FREE Live Cool Themes, Hide Apps   87510  8.7M   5,000,000+
# Sketch - Draw & Paint                               215644   25M  50,000,000+
# Pixel Draw - Number Art Coloring Book                  967  2.8M     100,000+
#
# ...

# %% [markdown]
# ### Dimension de mon dataframe

# %%
google_app.shape
# Out:
# (10841, 13)

# %% [markdown]
# ### Noms des colonnes

# %%
google_app.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# ### Affichage des valeurs de la colonne Rating

# %%
google_app["Rating"]
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %% [markdown]
# ### Affichage des valeur Null pour la colonne rating

# %%
google_app["Rating"].isna().sum()
# Out:
# 1474

# %% [markdown]
# ### Affichage des valeur Null pour le dataframe

# %%
google_app.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
google_app_sans_NAN = google_app.dropna()

# %%
google_app_sans_NAN.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
google_app_sans_NAN.shape
# Out:
# (9360, 13)

# %%
google_app_sans_NAN.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ### trier le dataframe selon la colonne rating

# %%
google_app_sans_NAN.sort_values(by = "Rating").head()
# Out:
#                                    App      Category  Rating Reviews  Size  \
# 625            House party - live chat        DATING     1.0       1  9.2M
# 6319  BJ Bridge Standard American 2018          GAME     1.0       1  4.9M
# 7926              Tech CU Card Manager       FINANCE     1.0       2  7.2M
# 7383                    Thistletown CI  PRODUCTIVITY     1.0       1  6.6M
# 5978     Truck Driving Test Class 3 BC        FAMILY     1.0       1  2.0M
#
#      Installs  Type  Price Content Rating        Genres    Last Updated  \
# 625       10+  Free      0     Mature 17+        Dating   July 31, 2018
# 6319   1,000+  Free      0       Everyone          Card    May 21, 2018
# 7926   1,000+  Free      0       Everyone       Finance   July 25, 2017
# 7383     100+  Free      0       Everyone  Productivity  March 15, 2018
# 5978      50+  Paid  $1.49       Everyone     Education   April 9, 2012
#
#      Current Ver   Android Ver
# 625         3.52  4.0.3 and up
# ...

# %% [markdown]
# ### type de toute les colonnes de dataframe

# %%
google_app_sans_NAN.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# ### describe : affiche des informations que sur les variable quantitatives

# %%
google_app_sans_NAN.describe()
# Out:
#             Rating
# count  9360.000000
# mean      4.191838
# std       0.515263
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max       5.000000

# %% [markdown]
# ### describe(include="all") : affiche des informations sur toutes les variable de la dataframe

# %%
google_app_sans_NAN.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count     9360     9360  9360.000000    9360                9360        9360
# unique    8190       33          NaN    5990                 413          19
# top     ROBLOX   FAMILY          NaN       2  Varies with device  1,000,000+
# freq         9     1746          NaN      83                1637        1576
# mean       NaN      NaN     4.191838     NaN                 NaN         NaN
# std        NaN      NaN     0.515263     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN     5.000000     NaN                 NaN         NaN
#
# ...

# %%
google_app_sans_NAN["Installs"] = google_app_sans_NAN["Installs"].apply(lambda x: x.replace(",",""))
google_app_sans_NAN["Installs"] = google_app_sans_NAN["Installs"].apply(lambda x: x.replace("+",""))
# Out:
# <ipython-input-386-e44c314aa35b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_app_sans_NAN["Installs"] = google_app_sans_NAN["Installs"].apply(lambda x: x.replace(",",""))
# <ipython-input-386-e44c314aa35b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_app_sans_NAN["Installs"] = google_app_sans_NAN["Installs"].apply(lambda x: x.replace("+",""))

# %%
google_app_sans_NAN.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google_app_sans_NAN.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
google_app_sans_NAN["Installs"] = google_app_sans_NAN["Installs"].apply(lambda x: int(x))
# Out:
# <ipython-input-389-9dcf37af4060>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_app_sans_NAN["Installs"] = google_app_sans_NAN["Installs"].apply(lambda x: int(x))

# %%
google_app_sans_NAN.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs            int64
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
google_app_sans_NAN.describe()
# Out:
#             Rating      Installs
# count  9360.000000  9.360000e+03
# mean      4.191838  1.790875e+07
# std       0.515263  9.126637e+07
# min       1.000000  1.000000e+00
# 25%       4.000000  1.000000e+04
# 50%       4.300000  5.000000e+05
# 75%       4.500000  5.000000e+06
# max       5.000000  1.000000e+09

# %%
google_app_sans_NAN["Reviews"] = google_app_sans_NAN["Reviews"].apply(lambda x: int(x))
# Out:
# <ipython-input-392-6d58283b9112>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_app_sans_NAN["Reviews"] = google_app_sans_NAN["Reviews"].apply(lambda x: int(x))

# %%
google_app_sans_NAN.describe()
# Out:
#             Rating       Reviews      Installs
# count  9360.000000  9.360000e+03  9.360000e+03
# mean      4.191838  5.143767e+05  1.790875e+07
# std       0.515263  3.145023e+06  9.126637e+07
# min       1.000000  1.000000e+00  1.000000e+00
# 25%       4.000000  1.867500e+02  1.000000e+04
# 50%       4.300000  5.955000e+03  5.000000e+05
# 75%       4.500000  8.162750e+04  5.000000e+06
# max       5.000000  7.815831e+07  1.000000e+09

# %% [markdown]
# ### regardez les groupes d'individus qui existent pour chaque colonne

# %%
google_app_sans_NAN["Type"].value_counts()
# Out:
# Free    8715
# Paid     645
# Name: Type, dtype: int64

# %% [markdown]
# # Filtrer un dataframe selon des conditions

# %%
google_app_sans_NAN.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159   19M     10000  Free     0       Everyone
# 1      967   14M    500000  Free     0       Everyone
# 2    87510  8.7M   5000000  Free     0       Everyone
# 3   215644   25M  50000000  Free     0           Teen
# 4      967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#google_app_sans_NAN[google_app_sans_NAN["Rating"]>4.5]
google_app_sans_NAN.loc[google_app_sans_NAN["Rating"]>4.5,:]
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10810                                  Fr Lupupa Sermons             BUSINESS
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
#
# ...

# %%
google_app_sans_NAN.loc[google_app_sans_NAN["Rating"]>4.5,:].shape
# Out:
# (1917, 13)

# %%
google_app_sans_NAN.loc[(google_app_sans_NAN["Rating"]>4.5) & (google_app_sans_NAN["Category"]=="BUSINESS"),:]
# Out:
#                                                      App  Category  Rating  \
# 196                           Job Search by ZipRecruiter  BUSINESS     4.8
# 206                                         Call Blocker  BUSINESS     4.6
# 208                           Square Point of Sale - POS  BUSINESS     4.6
# 221                                        Myanmar 2D/3D  BUSINESS     4.6
# 224                       ATI Cargoes and Transportation  BUSINESS     4.7
# ...                                                  ...       ...     ...
# 10412                                             FH App  BUSINESS     4.9
# 10529                                 FK CLASSIC FOR YOU  BUSINESS     5.0
# 10659                                                 FN  BUSINESS     5.0
# 10706  Neon Blue Gaming Wallpaper&Theme fo Lenovo K8 ...  BUSINESS     4.6
# 10810                                  Fr Lupupa Sermons  BUSINESS     4.8
#
# ...

# %%
google_app_sans_NAN["Category"].value_counts()
# Out:
# FAMILY                 1746
# GAME                   1097
# TOOLS                   733
# PRODUCTIVITY            351
# MEDICAL                 350
# COMMUNICATION           328
# FINANCE                 323
# SPORTS                  319
# PHOTOGRAPHY             317
# LIFESTYLE               314
# PERSONALIZATION         312
# BUSINESS                303
# HEALTH_AND_FITNESS      297
# SOCIAL                  259
# SHOPPING                238
# NEWS_AND_MAGAZINES      233
# TRAVEL_AND_LOCAL        226
# DATING                  195
# BOOKS_AND_REFERENCE     178
# VIDEO_PLAYERS           160
# EDUCATION               155
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     124
# FOOD_AND_DRINK          109
# HOUSE_AND_HOME           76
# WEATHER                  75
# AUTO_AND_VEHICLES        73
# LIBRARIES_AND_DEMO       64
# ART_AND_DESIGN           61
# COMICS                   58
# PARENTING                50
# EVENTS                   45
# BEAUTY                   42
# ...

# %%
google_app_sans_NAN.loc[(google_app_sans_NAN['Type']=="Paid") & (google_app_sans_NAN['Genres']=="Communication"),:].shape
# Out:
# (22, 13)

# %%
google_app_sans_NAN.loc[:,["Category","Rating"]]
# Out:
#                   Category  Rating
# 0           ART_AND_DESIGN     4.1
# 1           ART_AND_DESIGN     3.9
# 2           ART_AND_DESIGN     4.7
# 3           ART_AND_DESIGN     4.5
# 4           ART_AND_DESIGN     4.3
# ...                    ...     ...
# 10834               FAMILY     4.0
# 10836               FAMILY     4.5
# 10837               FAMILY     5.0
# 10839  BOOKS_AND_REFERENCE     4.5
# 10840            LIFESTYLE     4.5
#
# [9360 rows x 2 columns]

# %%
google_app_sans_NAN["Price"].value_counts()
google_app_sans_NAN["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$7.99', '$5.99', '$2.99', '$3.49',
#        '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49', '$10.00',
#        '$24.99', '$11.99', '$79.99', '$16.99', '$14.99', '$29.99',
#        '$12.99', '$2.49', '$10.99', '$1.50', '$19.99', '$15.99', '$33.99',
#        '$39.99', '$3.95', '$4.49', '$1.70', '$8.99', '$1.49', '$3.88',
#        '$399.99', '$17.99', '$400.00', '$3.02', '$1.76', '$4.84', '$4.77',
#        '$1.61', '$2.50', '$1.59', '$6.49', '$1.29', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$8.49', '$1.75', '$14.00', '$2.00',
#        '$3.08', '$2.59', '$19.40', '$3.90', '$4.59', '$15.46', '$3.04',
#        '$13.99', '$4.29', '$3.28', '$4.60', '$1.00', '$2.95', '$2.90',
#        '$1.97', '$2.56', '$1.20'], dtype=object)

# %%
google_app_sans_NAN["Price"] = google_app_sans_NAN["Price"].apply(lambda x: x.replace("$",""))
# Out:
# <ipython-input-403-a2bef9bbe144>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_app_sans_NAN["Price"] = google_app_sans_NAN["Price"].apply(lambda x: x.replace("$",""))

# %%
google_app_sans_NAN["Price"] = google_app_sans_NAN["Price"].apply(lambda x: float(x))
# Out:
# <ipython-input-404-c53192ecadc3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_app_sans_NAN["Price"] = google_app_sans_NAN["Price"].apply(lambda x: float(x))

# %%
google_app_sans_NAN["Price"].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   7.99,   5.99,   2.99,   3.49,
#          1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,  24.99,
#         11.99,  79.99,  16.99,  14.99,  29.99,  12.99,   2.49,  10.99,
#          1.5 ,  19.99,  15.99,  33.99,  39.99,   3.95,   4.49,   1.7 ,
#          8.99,   1.49,   3.88, 399.99,  17.99, 400.  ,   3.02,   1.76,
#          4.84,   4.77,   1.61,   2.5 ,   1.59,   6.49,   1.29, 299.99,
#        379.99,  37.99,  18.99, 389.99,   8.49,   1.75,  14.  ,   2.  ,
#          3.08,   2.59,  19.4 ,   3.9 ,   4.59,  15.46,   3.04,  13.99,
#          4.29,   3.28,   4.6 ,   1.  ,   2.95,   2.9 ,   1.97,   2.56,
#          1.2 ])

# %%
google_app_sans_NAN.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159   19M     10000  Free    0.0       Everyone
# 1      967   14M    500000  Free    0.0       Everyone
# 2    87510  8.7M   5000000  Free    0.0       Everyone
# 3   215644   25M  50000000  Free    0.0           Teen
# 4      967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google_app_sans_NAN.groupby("Category").head()
google_app_sans_NAN.groupby("Category").describe()
# Out:
#                      Rating                                                   \
#                       count      mean       std  min    25%  50%    75%  max
# Category
# ART_AND_DESIGN         61.0  4.377049  0.328326  3.4  4.100  4.4  4.700  5.0
# AUTO_AND_VEHICLES      73.0  4.190411  0.543692  2.1  4.000  4.3  4.600  4.9
# BEAUTY                 42.0  4.278571  0.362603  3.1  4.000  4.3  4.575  4.9
# BOOKS_AND_REFERENCE   178.0  4.346067  0.429046  2.7  4.100  4.5  4.600  5.0
# BUSINESS              303.0  4.121452  0.624422  1.0  3.900  4.3  4.500  5.0
# COMICS                 58.0  4.155172  0.537758  2.8  3.825  4.4  4.500  5.0
# COMMUNICATION         328.0  4.158537  0.426192  1.0  4.000  4.3  4.400  5.0
# DATING                195.0  3.970769  0.630510  1.0  3.700  4.1  4.400  5.0
# EDUCATION             155.0  4.389032  0.251894  3.5  4.200  4.4  4.600  4.9
# ENTERTAINMENT         149.0  4.126174  0.302556  3.0  3.900  4.2  4.300  4.7
# ...

# %%
google_app_sans_NAN.groupby(["Category","Genres"]).describe()
# Out:
#                                                         Rating            \
#                                                          count      mean
# Category          Genres
# ART_AND_DESIGN    Art & Design                            55.0  4.380000
#                   Art & Design;Creativity                  5.0  4.440000
#                   Art & Design;Pretend Play                1.0  3.900000
# AUTO_AND_VEHICLES Auto & Vehicles                         73.0  4.190411
# BEAUTY            Beauty                                  42.0  4.278571
# ...                                                        ...       ...
# TRAVEL_AND_LOCAL  Travel & Local;Action & Adventure        1.0  4.100000
# VIDEO_PLAYERS     Video Players & Editors                158.0  4.063924
#                   Video Players & Editors;Creativity       1.0  4.100000
#                   Video Players & Editors;Music & Video    1.0  4.000000
# ...

# %% [markdown]
# # EXERCICE

# %%
max_install = google_app_sans_NAN["Installs"].max()
max_install
# Out:
# 1000000000

# %%
google_app_sans_NAN.loc[google_app_sans_NAN["Installs"] == max_install,["App","Rating","Genres"]]
# Out:
#                                            App  Rating  \
# 152                          Google Play Books     3.9
# 335   Messenger – Text and Video Chat for Free     4.0
# 336                         WhatsApp Messenger     4.4
# 338               Google Chrome: Fast & Secure     4.3
# 340                                      Gmail     4.3
# 341                                   Hangouts     4.0
# 381                         WhatsApp Messenger     4.4
# 382   Messenger – Text and Video Chat for Free     4.0
# 386                                   Hangouts     4.0
# 391              Skype - free IM & video calls     4.1
# 411               Google Chrome: Fast & Secure     4.3
# 451                                      Gmail     4.3
# 464                                   Hangouts     4.0
# 468              Skype - free IM & video calls     4.1
# 865                          Google Play Games     4.3
# 1654                            Subway Surfers     4.5
# ...

# %%
max_review = google_app_sans_NAN["Reviews"].max()
max_review
# Out:
# 78158306

# %%
google_app_sans_NAN.loc[(google_app_sans_NAN["Reviews"]==max_review),["App","Rating"]]
# Out:
#            App  Rating
# 2544  Facebook     4.1

# %%
google_app_sans_NAN.iloc[2:16,[1,4,5]]
# Out:
#           Category  Size  Installs
# 2   ART_AND_DESIGN  8.7M   5000000
# 3   ART_AND_DESIGN   25M  50000000
# 4   ART_AND_DESIGN  2.8M    100000
# 5   ART_AND_DESIGN  5.6M     50000
# 6   ART_AND_DESIGN   19M     50000
# 7   ART_AND_DESIGN   29M   1000000
# 8   ART_AND_DESIGN   33M   1000000
# 9   ART_AND_DESIGN  3.1M     10000
# 10  ART_AND_DESIGN   28M   1000000
# 11  ART_AND_DESIGN   12M   1000000
# 12  ART_AND_DESIGN   20M  10000000
# 13  ART_AND_DESIGN   21M    100000
# 14  ART_AND_DESIGN   37M    100000
# 16  ART_AND_DESIGN  5.5M    500000

# %%
len(google_app_sans_NAN.loc[google_app_sans_NAN["Content Rating"]=="Everyone"])
google_app_sans_NAN.loc[google_app_sans_NAN["Content Rating"]=="Everyone"].shape
# Out:
# (7414, 13)

# %%
google_app_sans_NAN.groupby("Category").agg('count')
# Out:
#                       App  Rating  Reviews  Size  Installs  Type  Price  \
# Category
# ART_AND_DESIGN         61      61       61    61        61    61     61
# AUTO_AND_VEHICLES      73      73       73    73        73    73     73
# BEAUTY                 42      42       42    42        42    42     42
# BOOKS_AND_REFERENCE   178     178      178   178       178   178    178
# BUSINESS              303     303      303   303       303   303    303
# COMICS                 58      58       58    58        58    58     58
# COMMUNICATION         328     328      328   328       328   328    328
# DATING                195     195      195   195       195   195    195
# EDUCATION             155     155      155   155       155   155    155
# ENTERTAINMENT         149     149      149   149       149   149    149
# EVENTS                 45      45       45    45        45    45     45
# FAMILY               1746    1746     1746  1746      1746  1746   1746
# ...

# %%
max_prix = google_app_sans_NAN["Price"].max()

# %%
google_app_sans_NAN.loc[google_app_sans_NAN["Price"]==max_prix, :]
# Out:
#                            App   Category  Rating  Reviews  Size  Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6      275  7.3M       275
#
#       Type  Price Content Rating     Genres Last Updated Current Ver  \
# 4367  Paid  400.0       Everyone  Lifestyle  May 3, 2018       1.0.1
#
#      Android Ver
# 4367  4.1 and up
